# %%
from hstrader import HsTrader
from hstrader.models import Tick, Event, Resolution
import plotly.graph_objects as go
import pandas as pd
from datetime import timedelta
import os
from dotenv import load_dotenv
import logging
import asyncio
from psar import PSAR
from IPython.display import display, clear_output

# %%
psar = PSAR()
# Enable logging
logging.basicConfig(level=logging.INFO)

# Load environment variables
load_dotenv()

# Get the CLIENT_ID and CLIENT_SECRET from the environment variables
id = os.getenv('CLIENT_ID')
secret = os.getenv('CLIENT_SECRET')

# Initialize the HsTrader client with the client ID and secret
client = HsTrader(id, secret)

# %%
symbol = client.get_symbol('EURUSD')
data = client.get_market_history(symbol=symbol.id, resolution=Resolution.M1)

# Create a DataFrame from the retrieved data
df = pd.DataFrame([bar.model_dump() for bar in data])
df['time'] = pd.to_datetime(df['time'])
df.set_index('time', inplace=True)

# Update the DataFrame with PSAR trend values
df['psar'] = df.apply(lambda x: psar.calc_psar(x['high'], x['low']), axis=1)
df['Trend'] = psar.trend_list[:len(df)]

# %%
psar_bull = df.loc[df['Trend'] == 1]['psar']
psar_bear = df.loc[df['Trend'] == 0]['psar']
fig = go.FigureWidget()
candlestick = go.Candlestick(x=df.index, open=df['open'], high=df['high'], low=df['low'], close=df['close'], name='Candlestick')
fig.add_trace(candlestick)
# Add PSAR bull scatter
fig.add_trace(go.Scatter(x=psar_bull.index, y=psar_bull, mode='markers', name='Up Trend', marker=dict(color='green', size=2)))

# Add PSAR bear scatter
fig.add_trace(go.Scatter(x=psar_bear.index, y=psar_bear, mode='markers', name='Down Trend', marker=dict(color='red', size=2)))

CANDLE_INTERVAL = timedelta(minutes=1)
data = {
    'x': list(df.index),
    'open': list(df['open']),
    'high': list(df['high']),
    'low': list(df['low']),
    'close': list(df['close'])
}


@client.subscribe(Event.MARKET)
async def on_market(tick: Tick):
    global data, df

    if tick.symbol_id == symbol.id:
        tick_time = pd.to_datetime(tick.time)
        if not data['x']:
            data['x'].append(tick_time)
            data['open'].append(data['close'][-1])
            data['high'].append(tick.bid)
            data['low'].append(tick.bid)
            data['close'].append(tick.bid)
        elif tick_time >= data['x'][-1] + CANDLE_INTERVAL:
            data['x'].append(tick_time)
            data['open'].append(data['close'][-1])
            data['high'].append(tick.bid)
            data['low'].append(tick.bid)
            data['close'].append(tick.bid)
        else:
            data['low'][-1] = min(tick.bid, data['low'][-1])
            data['high'][-1] = max(tick.bid, data['high'][-1])
            data['close'][-1] = tick.bid

        df = pd.DataFrame({
            'time': data['x'],
            'open': data['open'],
            'high': data['high'],
            'low': data['low'],
            'close': data['close']
        }).set_index('time')

        # Calculate PSAR and trend list
        psar_values = []
        trend_values = []
        for i, row in df.iterrows():
            x = psar.calc_psar(row['high'], row['low'])
            psar_values.append(x)
            trend_values.append(psar.trend)  # Use the last trend value

        df['psar'] = psar_values
        df['Trend'] = trend_values

async def update_plot():
    while True:
        await asyncio.sleep(1)
        clear_output(wait=True)
        psar_bull = df.loc[df['Trend'] == 1]['psar']
        psar_bear = df.loc[df['Trend'] == 0]['psar']
        with fig.batch_update():
            fig.data[0].x = data['x']
            fig.data[0].open = data['open']
            fig.data[0].high = data['high']
            fig.data[0].low = data['low']
            fig.data[0].close = data['close']
            fig.data[1].x = psar_bull.index
            fig.data[1].y = psar_bull
            fig.data[2].x = psar_bear.index
            fig.data[2].y = psar_bear
        display(fig)


loop = asyncio.get_event_loop()
tasks = [
    client.start_async(),
    update_plot()
]
loop.run_until_complete(asyncio.gather(*tasks))
# Out:
# FigureWidget({
#     'data': [{'close': [1.09309, 1.09312, 1.09315, ..., 1.09237, 1.09217, 1.09243],
#               'high': [1.09315, 1.09316, 1.09321, ..., 1.09243, 1.0924, 1.09245],
#               'low': [1.09303, 1.09304, 1.09307, ..., 1.09227, 1.09212, 1.0921],
#               'name': 'Candlestick',
#               'open': [1.0931, 1.09309, 1.09312, ..., 1.09235, 1.09237, 1.09217],
#               'type': 'candlestick',
#               'uid': 'd441c2b9-287a-433d-9216-0ce6db7b8288',
#               'x': [2024-08-08 04:56:00+00:00, 2024-08-08 04:57:00+00:00,
#                     2024-08-08 04:58:00+00:00, ..., 2024-08-08 10:18:22+00:00,
#                     2024-08-08 10:19:22+00:00, 2024-08-08 10:20:22+00:00]},
#              {'marker': {'color': 'green', 'size': 2},
#               'mode': 'markers',
#               'name': 'Up Trend',
#               'type': 'scatter',
#               'uid': '5bb1fcde-7478-4ebb-ac01-b8cc947b8415',
#               'x': array([datetime.datetime(2024, 8, 8, 4, 56, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 4, 57, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 4, 58, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 4, 59, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 0, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 1, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 2, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 3, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 4, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 5, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 6, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 7, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 8, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 9, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 10, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 11, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 12, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 16, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 17, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 25, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 26, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 27, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 28, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 29, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 30, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 31, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 32, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 33, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 44, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 45, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 46, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 47, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 48, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 49, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 50, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 51, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 52, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 53, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 54, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 55, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 56, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 57, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 58, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 59, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 0, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 1, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 2, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 6, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 7, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 8, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 9, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 10, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 11, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 12, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 13, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 14, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 15, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 16, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 17, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 18, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 19, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 20, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 21, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 34, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 35, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 36, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 37, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 38, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 39, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 40, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 41, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 42, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 43, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 44, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 45, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 46, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 47, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 48, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 49, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 50, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 51, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 56, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 57, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 58, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 59, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 0, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 1, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 2, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 3, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 4, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 5, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 6, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 7, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 19, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 20, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 21, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 35, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 36, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 52, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 53, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 54, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 55, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 56, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 57, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 58, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 59, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 0, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 1, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 2, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 3, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 4, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 6, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 7, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 8, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 9, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 10, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 11, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 12, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 13, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 14, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 15, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 16, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 17, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 18, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 34, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 35, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 36, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 37, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 38, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 39, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 40, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 41, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 42, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 43, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 44, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 45, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 46, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 47, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 48, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 49, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 5, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 6, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 7, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 8, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 9, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 10, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 27, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 28, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 29, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 30, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 31, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 32, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 33, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 34, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 54, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 55, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 56, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 57, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 58, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 59, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 0, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 16, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 17, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 18, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 19, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 20, 22, tzinfo=TzInfo(UTC))],
#                          dtype=object),
#               'y': array([1.09208073, 1.0921    , 1.092206  , 1.09232648, 1.0924325 , 1.09254975,
#                           1.09265059, 1.0927373 , 1.09282734, 1.09290296, 1.09296649, 1.093     ,
#                           1.093     , 1.09302   , 1.09302   , 1.09305   , 1.09308   , 1.09307   ,
#                           1.0930748 , 1.09299   , 1.09299   , 1.0929954 , 1.09300069, 1.09300588,
#                           1.09301096, 1.09301594, 1.09302082, 1.09302561, 1.09291   , 1.0929164 ,
#                           1.09292267, 1.09292882, 1.09293484, 1.09294075, 1.09294653, 1.0929522 ,
#                           1.09296491, 1.09298502, 1.09301422, 1.09305179, 1.09309598, 1.09315114,
#                           1.09320696, 1.09327231, 1.09332589, 1.09338271, 1.09343617, 1.09345   ,
#                           1.09345   , 1.0934554 , 1.09346069, 1.09346588, 1.09347096, 1.09348812,
#                           1.09353263, 1.09357448, 1.09361381, 1.09365078, 1.09368553, 1.0937182 ,
#                           1.09374891, 1.09377777, 1.09381555, 1.09329   , 1.0932996 , 1.09330901,
#                           1.09331823, 1.09332726, 1.09333612, 1.09335627, 1.09337562, 1.09340709,
#                           1.09345372, 1.09349662, 1.09353609, 1.0935724 , 1.09360581, 1.09364623,
#                           1.09369708, 1.09376889, 1.09385547, 1.09381   , 1.0938208 , 1.09384677,
#                           1.0938717 , 1.09389563, 1.0939186 , 1.09394066, 1.09397422, 1.09400577,
#                           1.09403542, 1.0940633 , 1.0940895 , 1.09355   , 1.0935622 , 1.09358771,
#                           1.0936122 , 1.09354   , 1.0935504 , 1.09331   , 1.0933162 , 1.09333195,
#                           1.09335763, 1.09339702, 1.09344632, 1.09351516, 1.09357574, 1.09362905,
#                           1.09368519, 1.09373346, 1.09377   , 1.09381   , 1.09396   , 1.09385   ,
#                           1.0938664 , 1.09389062, 1.09391338, 1.09394271, 1.09396969, 1.09399452,
#                           1.09401   , 1.094058  , 1.09411008, 1.09415487, 1.09417   , 1.09347   ,
#                           1.0934766 , 1.09349114, 1.09351327, 1.09353407, 1.09356575, 1.09359489,
#                           1.0936217 , 1.09365553, 1.09368597, 1.09371338, 1.09374897, 1.09378029,
#                           1.09382   , 1.09384   , 1.0938976 , 1.09347   , 1.09347   , 1.0934872 ,
#                           1.09351617, 1.0935434 , 1.09356899, 1.09302   , 1.093025  , 1.0930356 ,
#                           1.09305446, 1.09308451, 1.09311215, 1.09314493, 1.09317444, 1.09253   ,
#                           1.0925354 , 1.09254069, 1.09255266, 1.0925711 , 1.09259822, 1.0926    ,
#                           1.09201   , 1.0920178 , 1.09202544, 1.09204163, 1.09205716])},
#              {'marker': {'color': 'red', 'size': 2},
#               'mode': 'markers',
#               'name': 'Down Trend',
#               'type': 'scatter',
#               'uid': '8d2c8c16-e654-49cb-a1a6-cb07bd27e2d5',
#               'x': array([datetime.datetime(2024, 8, 8, 5, 13, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 14, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 15, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 18, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 19, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 20, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 21, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 23, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 24, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 34, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 35, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 36, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 37, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 38, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 39, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 40, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 41, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 42, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 5, 43, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 3, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 4, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 5, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 23, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 24, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 25, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 26, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 27, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 28, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 29, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 30, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 31, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 32, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 33, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 52, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 53, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 54, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 6, 55, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 8, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 9, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 10, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 11, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 12, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 13, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 14, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 15, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 16, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 17, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 18, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 23, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 24, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 25, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 26, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 27, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 28, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 29, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 30, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 31, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 32, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 33, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 34, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 37, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 38, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 39, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 40, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 41, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 42, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 43, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 44, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 45, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 46, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 47, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 48, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 49, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 50, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 7, 51, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 5, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 19, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 20, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 21, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 23, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 24, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 25, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 26, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 27, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 28, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 29, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 30, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 31, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 32, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 33, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 50, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 51, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 52, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 53, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 54, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 55, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 56, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 57, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 58, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 8, 59, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 0, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 1, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 2, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 3, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 4, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 11, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 12, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 13, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 14, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 15, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 16, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 17, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 18, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 19, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 20, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 21, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 23, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 24, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 25, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 26, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 35, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 36, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 37, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 38, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 39, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 40, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 41, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 42, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 43, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 44, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 45, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 46, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 47, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 48, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 49, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 50, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 51, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 52, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 9, 53, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 1, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 2, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 3, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 4, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 5, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 6, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 7, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 8, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 9, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 10, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 11, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 12, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 13, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 14, 22, tzinfo=TzInfo(UTC)),
#                           datetime.datetime(2024, 8, 8, 10, 15, 22, tzinfo=TzInfo(UTC))],
#                          dtype=object),
#               'y': array([1.0933    , 1.0932958 , 1.09328677, 1.09328   , 1.09328   , 1.09327   ,
#                           1.0932538 , 1.09323857, 1.09321869, 1.09320039, 1.09325   , 1.093245  ,
#                           1.0932316 , 1.09321874, 1.09320639, 1.09319453, 1.09318315, 1.09317222,
#                           1.09316173, 1.09315167, 1.09371   , 1.09371   , 1.0937046 , 1.09425   ,
#                           1.0942386 , 1.09421226, 1.09418697, 1.09416269, 1.09412353, 1.09406404,
#                           1.09399064, 1.09392458, 1.09385083, 1.09377231, 1.09370479, 1.09431   ,
#                           1.0943014 , 1.09428174, 1.09426287, 1.0945    , 1.094492  , 1.09447232,
#                           1.09443798, 1.0944057 , 1.09437536, 1.09434684, 1.09429349, 1.09423014,
#                           1.09414853, 1.0940767 , 1.0942    , 1.0941886 , 1.09417743, 1.09416648,
#                           1.09414422, 1.09412285, 1.09408908, 1.09404515, 1.09400474, 1.09396756,
#                           1.09393336, 1.09390189, 1.09401   , 1.09401   , 1.0939872 , 1.09396531,
#                           1.0939443 , 1.09392413, 1.09390476, 1.09388617, 1.0938576 , 1.09383075,
#                           1.0938055 , 1.09377306, 1.09372675, 1.09368508, 1.09364757, 1.09416   ,
#                           1.09443   , 1.0944242 , 1.09440963, 1.09437905, 1.09435031, 1.09432329,
#                           1.09428783, 1.09423905, 1.09417076, 1.09411067, 1.09405779, 1.09401125,
#                           1.09395928, 1.09391   , 1.09386   , 1.09416   , 1.0941552 , 1.09414379,
#                           1.09412616, 1.09410087, 1.0940776 , 1.09405619, 1.0940365 , 1.09401838,
#                           1.09398354, 1.09393272, 1.09387494, 1.09382524, 1.0938    , 1.0938    ,
#                           1.09397   , 1.09396   , 1.093938  , 1.09389972, 1.09386374, 1.09382991,
#                           1.09378192, 1.09371273, 1.09365045, 1.09359441, 1.09354397, 1.09348349,
#                           1.09342   , 1.0933654 , 1.09331845, 1.0932707 , 1.09344   , 1.0934346 ,
#                           1.09342162, 1.09339692, 1.09335957, 1.0933252 , 1.09329358, 1.0932645 ,
#                           1.09323774, 1.09321312, 1.09319047, 1.09315342, 1.09312   , 1.0930768 ,
#                           1.09303878, 1.09298295, 1.09293494, 1.09287015, 1.09282   , 1.09291   ,
#                           1.092903  , 1.09288528, 1.09285556, 1.09282763, 1.09278942, 1.09272548,
#                           1.09265522, 1.09259339, 1.09251872, 1.09243732, 1.09236895, 1.09236   ,
#                           1.09236   , 1.09233   ])}],
#     'layout': {'autosize': True, 'template': '...'}
# })
